# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("Uncleaned_DS_jobs.csv",index_col="index")
df.sample(10)
# Out:
#                                               Job Title  \
# index
# 77                                       Data Scientist
# 526                        Scientist - Machine Learning
# 556    Senior Machine Learning Scientist - Bay Area, CA
# 313                                      Data Scientist
# 324                                      Data Scientist
# 249                                Computer Scientist 1
# 168                                       Data Engineer
# 420                                      Data Scientist
# 599                                      Data Scientist
# 370                               AI Ops Data Scientist
#
#                     Salary Estimate  \
# index
# 77      $79K-$131K (Glassdoor est.)
# 526    $212K-$331K (Glassdoor est.)
# 556    $128K-$201K (Glassdoor est.)
# 313      $145K-$225K(Employer est.)
# 324     $79K-$147K (Glassdoor est.)
# 249     $90K-$124K (Glassdoor est.)
# 168    $101K-$165K (Glassdoor est.)
# 420    $124K-$198K (Glassdoor est.)
# 599     $80K-$132K (Glassdoor est.)
# 370    $112K-$116K (Glassdoor est.)
#
#                                          Job Description  Rating  \
# index
# 77     WHAT WE DO MATTERS:\n\nHere at The Knot Worldw...     3.5
# 526    Scientist 1 - Machine Learning - Cell Science\...     3.5
# 556    Passionate about precision medicine and advanc...     3.3
# 313    Data Scientist\n\nJob Introduction\nFLEETCOR i...     3.5
# 324    Job Description\n\nThe Cooking Lab is the publ...     3.3
# 249    Computer Scientist\n\nNSBU | Melbourne, FL, Un...     4.2
# 168    Job Number: 10202\nGroup: Cosma International\...     3.5
# 420    Description Our client is looking to hire a da...     3.5
# 599    Overview\n\n\nEnvision Physician Services is a...     2.9
# 370    Company\n\nAstraZeneca is a global, innovation...     4.0
#
#                            Company Name          Location  \
# index
# 77              The Knot Worldwide\n3.5    Washington, DC
# 526                Allen Institute\n3.5       Seattle, WA
# 556                    Tempus Labs\n3.3  Redwood City, CA
# 313                   Cambridge FX\n3.5       Atlanta, GA
# 324          Intellectual Ventures\n3.3      Bellevue, WA
# 249    Rincon Research Corporation\n4.2     Melbourne, FL
# 168       Magna International Inc.\n3.5    Birmingham, AL
# 420                    Robert Half\n3.5    Manchester, NH
# 599            Envision Healthcare\n2.9     Nashville, TN
# 370                    AstraZeneca\n4.0  Gaithersburg, MD
#
#                     Headquarters                    Size  Founded  \
# index
# 77               Chevy Chase, MD  1001 to 5000 employees     2019
# 526                  Seattle, WA    201 to 500 employees     2003
# 556                  Chicago, IL   501 to 1000 employees     2015
# 313              Toronto, Canada    201 to 500 employees     1992
# 324                 Bellevue, WA   501 to 1000 employees     2000
# 249                   Tucson, AZ    201 to 500 employees     1983
# 168               Aurora, Canada        10000+ employees     1957
# 420               Menlo Park, CA        10000+ employees     1948
# 599                Nashville, TN        10000+ employees     2005
# 370    Cambridge, United Kingdom        10000+ employees     1913
#
#             Type of ownership                               Industry  \
# index
# 77          Company - Private                               Internet
# 526    Nonprofit Organization                 Research & Development
# 556         Company - Private              Biotech & Pharmaceuticals
# 313          Company - Public       Financial Transaction Processing
# 324         Company - Private  Investment Banking & Asset Management
# 249         Company - Private                    Aerospace & Defense
# 168          Company - Public                                     -1
# 420          Company - Public                 Staffing & Outsourcing
# 599         Company - Private       Health Care Services & Hospitals
# 370          Company - Public              Biotech & Pharmaceuticals
#
#                           Sector                     Revenue  \
# index
# 77        Information Technology    Unknown / Non-Applicable
# 526            Business Services  $100 to $500 million (USD)
# 556    Biotech & Pharmaceuticals    Unknown / Non-Applicable
# 313                      Finance  $100 to $500 million (USD)
# 324                      Finance    Unknown / Non-Applicable
# 249          Aerospace & Defense   $50 to $100 million (USD)
# 168                           -1          $10+ billion (USD)
# 420            Business Services      $2 to $5 billion (USD)
# 599                  Health Care    Unknown / Non-Applicable
# 370    Biotech & Pharmaceuticals          $10+ billion (USD)
#
#                                              Competitors
# index
# 77                                         Zola Registry
# 526                                                   -1
# 556                                                   -1
# 313                                                   -1
# 324                                                   -1
# 249    Raytheon Technologies, General Dynamics, MIT L...
# 168                    Bosch, Lear Corporation, Faurecia
# 420                                     Adecco, Manpower
# 599                                                   -1
# 370                     Roche, GlaxoSmithKline, Novartis

# %%
## fix the columns
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 672 entries, 0 to 671
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job_title          672 non-null    object
#  1   salary_estimate    672 non-null    object
#  2   job_description    672 non-null    object
#  3   rating             672 non-null    float64
#  4   company_name       672 non-null    object
#  5   location           672 non-null    object
#  6   headquarters       672 non-null    object
#  7   size               672 non-null    object
#  8   founded            672 non-null    int64
#  9   type_of_ownership  672 non-null    object
#  10  industry           672 non-null    object
#  11  sector             672 non-null    object
#  12  revenue            672 non-null    object
#  13  competitors        672 non-null    object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 78.8+ KB

# %%
## check null
df.isnull().sum()
# Out:
# job_title            0
# salary_estimate      0
# job_description      0
# rating               0
# company_name         0
# location             0
# headquarters         0
# size                 0
# founded              0
# type_of_ownership    0
# industry             0
# sector               0
# revenue              0
# competitors          0
# dtype: int64

# %%
## check uniques 
df.nunique()
# Out:
# job_title            172
# salary_estimate       30
# job_description      489
# rating                32
# company_name         432
# location             207
# headquarters         229
# size                   9
# founded              103
# type_of_ownership     13
# industry              58
# sector                23
# revenue               14
# competitors          108
# dtype: int64

# %% [markdown]
# # Check and clean data column by column
# ## Job Title
#
# ### Findings

# %%
df["job_title"].unique()
# Out:
# array(['Sr Data Scientist', 'Data Scientist',
#        'Data Scientist / Machine Learning Expert',
#        'Staff Data Scientist - Analytics',
#        'Data Scientist - Statistics, Early Career', 'Data Modeler',
#        'Experienced Data Scientist', 'Data Scientist - Contract',
#        'Data Analyst II', 'Medical Lab Scientist',
#        'Data Scientist/Machine Learning', 'Human Factors Scientist',
#        'Business Intelligence Analyst I- Data Insights',
#        'Data Scientist - Risk', 'Data Scientist-Human Resources',
#        'Senior Research Statistician- Data Scientist', 'Data Engineer',
#        'Associate Data Scientist', 'Business Intelligence Analyst',
#        'Senior Analyst/Data Scientist', 'Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst I',
#        'Scientist - Molecular Biology',
#        'Computational Scientist, Machine Learning',
#        'Senior Data Scientist', 'Jr. Data Engineer',
#        'E-Commerce Data Analyst', 'Data Analytics Engineer',
#        'Product Data Scientist - Ads Data Science',
#        'Data Scientist - Intermediate', 'Global Data Analyst',
#        'Data & Machine Learning Scientist',
#        'Data Scientist - Machine Learning', 'Data Engineer (Remote)',
#        'Data Scientist, Applied Machine Learning - Bay Area',
#        'Principal Data Scientist', 'Business Data Analyst',
#        'Purification Scientist', 'Data Engineer, Enterprise Analytics',
#        'Data Scientist 3 (718)', 'Real World Science, Data Scientist',
#        'Data Scientist - Image and Video Analytics',
#        'Data Science Manager, Payment Acceptance - USA',
#        'Data Scientist / Applied Mathematician',
#        'Patient Safety- Associate Data Scientist',
#        '(Sr.) Data Scientist -', 'Data Scientist, Kinship - NYC/Portland',
#        'Applied Technology Researcher / Data Scientist',
#        'Health Data Scientist - Biomedical/Biostats',
#        'Staff Data Scientist', 'Sr Data Engineer (Sr BI Developer)',
#        'Lead Data Scientist', 'RFP Data Analyst',
#        'Data Scientist (TS/SCI)', 'Software Engineer - Data Science',
#        'Data Analyst/Engineer', 'NGS Scientist', 'Senior Data Engineer',
#        'Sr. ML/Data Scientist - AI/NLP/Chatbot',
#        'Data Integration and Modeling Engineer',
#        'Tableau Data Engineer 20-0117', 'AI Data Scientist',
#        'Research Scientist Patient Preferences (Remote)',
#        'Scientist - Biomarker and Flow Cytometry', 'Analytics Manager',
#        'Staff Scientist- Upstream PD',
#        'Sr Scientist - Extractables & Leachables',
#        'ELISA RESEARCH SCIENTIST (CV-15)', 'Say Business Data Analyst',
#        'Geospatial Data Scientist', 'Computational Scientist',
#        'Senior Data Analyst', 'Sr Data Analyst',
#        'Machine Learning Scientist - Bay Area, CA',
#        'Senior Data Scientist - Algorithms',
#        'Senior Data & Machine Learning Scientist',
#        'Research Scientist - Patient-Centered Research (Remote)',
#        'Jr. Business Data Analyst (position added 6/12/2020)',
#        'Sr. Data Scientist II',
#        'Production Engineer - Statistics/Data Analysis',
#        'Statistical Scientist', 'Computational Behavioral Scientist',
#        'Principal Data Scientist - Machine Learning',
#        'Principal Machine Learning Scientist',
#        'Senior Data Scientist - R&D Oncology',
#        'Health Plan Data Analyst, Sr',
#        'Principal Scientist/Associate Director, Quality Control and Analytical Technologies',
#        'Analytics - Business Assurance Data Analyst',
#        'Senior Data Scientist – Image Analytics, Novartis AI Innovation Lab',
#        'Data Science Instructor', 'Senior Business Intelligence Analyst',
#        'In-Line Inspection Data Analyst',
#        'Data Scientist - TS/SCI FSP or CI Required',
#        'Data Scientist - TS/SCI Required',
#        'Data Science Software Engineer',
#        'ENGINEER - COMPUTER SCIENTIST - RESEARCH COMPUTER SCIENTIST - SIGNAL PROCESSING - SAN ANTONIO OR',
#        'AI Ops Data Scientist', 'Intelligence Data Analyst, Senior',
#        'Analytics Manager - Data Mart',
#        'Data Modeler (Analytical Systems)',
#        'Senior Machine Learning Scientist - Bay Area, CA',
#        'Report Writer-Data Analyst', 'Staff Data Scientist - Pricing',
#        'Equity Data Insights Analyst - Quantitative Analyst',
#        'Operations Data Analyst', 'Software Data Engineer',
#        'Real World Evidence (RWE) Scientist', 'Computer Scientist 1',
#        'Environmental Data Science', 'Staff BI and Data Engineer',
#        'Data Scientist - Statistics, Mid-Career',
#        'Director of Data Science',
#        'Data Engineer, Digital & Comp Pathology',
#        'Manager / Lead, Data Science & Analytics',
#        'Diversity and Inclusion Data Analyst',
#        'Data Scientist Machine Learning', 'Chief Scientist',
#        'Development Scientist, Voltaren',
#        'Principal Data & Analytics Platform Engineer',
#        'Machine Learning Engineer/Scientist',
#        'Data Analyst - Unilever Prestige', 'VP, Data Science',
#        'Data Engineer - Kafka', 'Decision Scientist',
#        'Data Science All Star Program - Data Engineer Track',
#        'Scientist - Machine Learning', 'Sr. Data Scientist',
#        'Applied AI Scientist / Engineer',
#        'Data Engineer (Analytics, SQL, Python, AWS)',
#        'Senior Data Analyst - Finance & Platform Analytics',
#        'Market Research Data Scientist',
#        'IT Partner Digital Health Technology and Data Science',
#        'Software Engineer (Data Scientist, C,C++,Linux,Unix) - SISW - MG',
#        'Senior Clinical Data Scientist Programmer',
#        'Computer Vision / Deep Learning Scientist',
#        'Data Solutions Engineer - Data Modeler',
#        'Data Scientist (TS/SCI w/ Poly)',
#        'Weapons and Sensors Engineer/Scientist',
#        'Applied Computer Scientist', 'Cloud Data Engineer (Azure)',
#        'Lead Certified Clinical Laboratory Scientist - Saturday - Tuesday, 8:00pm - 6:30am shift',
#        'Sr. Data Analyst',
#        'Senior Scientist - Toxicologist - Product Integrity (Stewardship)',
#        'Senior Machine Learning Engineer',
#        'Data Scientist- Industrial Discrete Sector Industry',
#        'Senior Principal Data Scientist (Python/R)',
#        'Data Scientist(s)/Machine Learning Engineer',
#        'Scientist / Group Lead, Cancer Biology',
#        'Manager, Field Application Scientist, Southeast',
#        'COMPUTER SCIENTIST - ENGINEER - RESEARCH COMPUTER SCIENTIST - SIGNAL PROCESSING',
#        'Machine Learning Scientist / Engineer', 'Data Science Analyst',
#        'COMPUTER SCIENTIST - ENGINEER - RESEARCH COMPUTER SCIENTIST - TRANSPORTATION TECHNOLOGY',
#        'Software Engineer - Machine Learning & Data Science (Applied Intelligence Services Team)',
#        'Clinical Data Analyst', 'Data Scientist Technical Specialist',
#        'Data Science Manager', 'Big Data Engineer', 'Data Architect',
#        'Aviation AI/ML Data Scientist', 'Machine Learning Engineer, Sr.',
#        'Information Systems Engineering Specialist (Engineering Scientist)',
#        'Scientist/Research Associate-Metabolic Engineering',
#        'Vice President, Biometrics and Clinical Data Management',
#        'Enterprise Data Analyst (Enterprise Portfolio Management Office)',
#        'Lead Data Scientist – Network Analysis and Control',
#        'Sr. Research Associate/ Scientist, NGS prep & Molecular Genomics',
#        'Developer III - Data Science',
#        'Hydrogen/Tritium Materials Scientist (Experienced)',
#        'Data Scientist/Data Analytics Practitioner',
#        'AI/ML - Machine Learning Scientist, Siri Understanding'],
#       dtype=object)

# %%
# total values
df["job_title"].count()
# Out:
# 672

# %%
# check the distribution of job titles
df["job_title"].value_counts().head(7)
# Out:
# Data Scientist               337
# Data Engineer                 26
# Senior Data Scientist         19
# Machine Learning Engineer     16
# Data Analyst                  12
# Senior Data Analyst            6
# Senior Data Engineer           5
# Name: job_title, dtype: int64

# %%
# visualize it with pie plot
def pie_jobs(df:pd.Series,top):
    top=df.value_counts().head(top)
    others=pd.Series([df.count()-top.sum()])
    others.rename(index={0:"others"},inplace=True)
    titles=pd.concat([top,others])

    plt.pie(titles,labels=titles.index,labeldistance=1.5,shadow=True,autopct='%1.1f%%')
    plt.figure(figsize=(1,2))
    plt.show()
    
    return df.value_counts().tail(df.nunique()-5)
# regard top 7 as majority
others=pie_jobs(df["job_title"],5)
others.index
# Out:
# Index(['Senior Data Analyst', 'Senior Data Engineer',
#        'Data Science Software Engineer',
#        'ENGINEER - COMPUTER SCIENTIST - RESEARCH COMPUTER SCIENTIST - SIGNAL PROCESSING - SAN ANTONIO OR',
#        'Data Scientist - TS/SCI FSP or CI Required',
#        'Principal Data Scientist', 'Sr. ML/Data Scientist - AI/NLP/Chatbot',
#        'AI Ops Data Scientist', 'Data Modeler (Analytical Systems)',
#        'Lead Data Scientist',
#        ...
#        'Computational Scientist, Machine Learning', 'Jr. Data Engineer',
#        'E-Commerce Data Analyst', 'Global Data Analyst',
#        'Data Engineer (Remote)', 'Data Science Instructor',
#        'Business Data Analyst', 'Purification Scientist',
#        'Data Engineer, Enterprise Analytics',
#        'AI/ML - Machine Learning Scientist, Siri Understanding'],
#       dtype='object', length=167)

# %% [markdown]
# - ### Problems
#     * too many uniqueness
#     * two or more roles per person("/" )presents
#     * all roles some how duplicated in many ways
#     * There are only 4 super categories
#         1. data scientist
#         2. data analyst
#         3. data engineer
#         4. Machine learning or AI modeling engineer
#     * there are also seniority in the tiles
#
# - ### Solutions
#     * create main and sub roles column
#     * create discrete integer column called senority, raise the number according to experience required(0,1,2,3: "no experience","junior level","senior level")

# %%
def createMainRole(df:pd.DataFrame):
    new_role=[]
    for row in df["job_title"].values:
        if ("data scientist"in row.lower() and ("ai" in row.lower() or "machine learning" in row.lower())):
            new_role.append("AI/ machine learning professionle")
        elif ("data scientist" in row.lower()):
            new_role.append("data scientist")
        elif ("analyst" in row.lower()):
            new_role.append("data analyst/analyst")
        elif ("ai" in row.lower() or "machine learning" in row.lower()):
            new_role.append("AI/ machine learning professionle")
        elif ("data engineer" in row.lower()):
            new_role.append("data engineer")
        else:
            new_role.append("others/scientist/software engineer(data concerning role)")
        df["main_role"]=pd.Series(new_role)

# %%
def createSenority(df:pd.DataFrame):
    senior=[]
    for row in df["job_title"].values:
        if ("senior"in row.lower() or "sr" in row.lower() or "experienced" in row.lower()):
            senior.append("Sr")
        elif ("junior" in row.lower() or "jr" in row.lower() or "staff" in row.lower()):
            senior.append("jr")
        else:
            senior.append("neutral")
        df["seniority"]=pd.Series(senior)

# %%
def createSubRole(df:pd.DataFrame):
    roles=[]
    for (row,find) in zip(df["job_title"].values,df["main_role"].values):
        if (find=="data scientist"):
            roles.append(row.replace("Data Scientist",""))
        elif (find=="AI/ machine learning professionle"):
            roles.append(row.replace("AI","").replace("Machine Learning",""))
        elif(find=="data analyst/analyst"):
            roles.append(row.replace("Data Analyst","").replace("Analyst",""))
        else:
            roles.append(row.replace("Data Engineer",""))
                        
    df["sub_role"]=pd.Series(roles)

# %%
createMainRole(df)

# %%
createSenority(df)

# %%
createSubRole(df)

# %%
df.sample(7)
# Out:
#                        job_title               salary_estimate  \
# index
# 368               Data Scientist  $112K-$116K (Glassdoor est.)
# 555               Data Scientist  $128K-$201K (Glassdoor est.)
# 91     Machine Learning Engineer   $79K-$131K (Glassdoor est.)
# 121         Senior Data Engineer   $99K-$132K (Glassdoor est.)
# 289               Data Scientist  $141K-$225K (Glassdoor est.)
# 362               Data Scientist  $122K-$146K (Glassdoor est.)
# 287               Data Scientist  $141K-$225K (Glassdoor est.)
#
#                                          job_description  rating  \
# index
# 368    Job Description\nOur client is committed to un...     4.7
# 555    Job Description\nAs a Data Scientist, you will...    -1.0
# 91     Machine Learning Engineer Springfield, VA\n\nM...     4.4
# 121    About Scoop\n\nScoop brings co-workers and nei...     4.7
# 289    We're looking for data scientists to work on o...     3.4
# 362    Job Overview: The Data Scientist is a key memb...    -1.0
# 287    For many of our team members, this is more tha...     4.2
#
#                         company_name           location       headquarters  \
# index
# 368    Compass Consulting Group\n4.7  Thousand Oaks, CA       Danville, CA
# 555                           HireAi  San Francisco, CA                 -1
# 91             NuWave Solutions\n4.4    Springfield, VA        Mc Lean, VA
# 121                       Scoop\n4.7  San Francisco, CA  San Francisco, CA
# 289                      Mackin\n3.4     Menlo Park, CA     Pittsburgh, PA
# 362                   Hatch Data Inc  San Francisco, CA                 -1
# 287         Oshkosh Corporation\n4.2        Oshkosh, WI        Oshkosh, WI
#
#                       size  founded  type_of_ownership  \
# index
# 368    51 to 200 employees     2008  Company - Private
# 555                     -1       -1                 -1
# 91     51 to 200 employees     1999  Company - Private
# 121    51 to 200 employees     2015  Company - Private
# 289    51 to 200 employees     1960  Company - Private
# 362                     -1       -1                 -1
# 287       10000+ employees     1917   Company - Public
#
#                                      industry                  sector  \
# index
# 368                                Consulting       Business Services
# 555                                        -1                      -1
# 91                                IT Services  Information Technology
# 121                                  Internet  Information Technology
# 289      Architectural & Engineering Services       Business Services
# 362                                        -1                      -1
# 287    Transportation Equipment Manufacturing           Manufacturing
#
#                         revenue                               competitors  \
# index
# 368    Unknown / Non-Applicable                                        -1
# 555                          -1                                        -1
# 91      $5 to $10 million (USD)                                        -1
# 121    Unknown / Non-Applicable                                        -1
# 289    $10 to $25 million (USD)                                        -1
# 362                          -1                                        -1
# 287     $5 to $10 billion (USD)  Lockheed Martin, Caterpillar, John Deere
#
#                                main_role seniority   sub_role
# index
# 368                       data scientist   neutral
# 555                       data scientist   neutral
# 91     AI/ machine learning professionle   neutral   Engineer
# 121                        data engineer        Sr    Senior
# 289                       data scientist   neutral
# 362                       data scientist   neutral
# 287                       data scientist   neutral

# %%
df["main_role"].value_counts()
# Out:
# data scientist                                              431
# others/scientist/software engineer(data concerning role)     78
# AI/ machine learning professionle                            61
# data analyst/analyst                                         55
# data engineer                                                47
# Name: main_role, dtype: int64

# %%
df["seniority"].value_counts()
# Out:
# neutral    585
# Sr          79
# jr           8
# Name: seniority, dtype: int64

# %%
pie_jobs(df["main_role"],5)
# Out:
# Series([], Name: main_role, dtype: int64)

# %%
df.loc[df["main_role"]=="AI/ machine learning professionle"][["job_title","main_role","sub_role"]].sample(10)
# Out:
#                                          job_title  \
# index
# 41                       Machine Learning Engineer
# 511    Data Scientist(s)/Machine Learning Engineer
# 179                      Machine Learning Engineer
# 134                      Machine Learning Engineer
# 215                          AI Ops Data Scientist
# 535          Machine Learning Scientist / Engineer
# 653         Sr. ML/Data Scientist - AI/NLP/Chatbot
# 330                      Machine Learning Engineer
# 101                      Machine Learning Engineer
# 405               Senior Machine Learning Engineer
#
#                                main_role                              sub_role
# index
# 41     AI/ machine learning professionle                              Engineer
# 511    AI/ machine learning professionle           Data Scientist(s)/ Engineer
# 179    AI/ machine learning professionle                              Engineer
# 134    AI/ machine learning professionle                              Engineer
# 215    AI/ machine learning professionle                    Ops Data Scientist
# 535    AI/ machine learning professionle                  Scientist / Engineer
# 653    AI/ machine learning professionle  Sr. ML/Data Scientist - /NLP/Chatbot
# 330    AI/ machine learning professionle                              Engineer
# 101    AI/ machine learning professionle                              Engineer
# 405    AI/ machine learning professionle                      Senior  Engineer

# %% [markdown]
# ## Salary Estimate

# %%
## checking uniqueness
df["salary_estimate"].unique()
# Out:
# array(['$137K-$171K (Glassdoor est.)', '$75K-$131K (Glassdoor est.)',
#        '$79K-$131K (Glassdoor est.)', '$99K-$132K (Glassdoor est.)',
#        '$90K-$109K (Glassdoor est.)', '$101K-$165K (Glassdoor est.)',
#        '$56K-$97K (Glassdoor est.)', '$79K-$106K (Glassdoor est.)',
#        '$71K-$123K (Glassdoor est.)', '$90K-$124K (Glassdoor est.)',
#        '$91K-$150K (Glassdoor est.)', '$141K-$225K (Glassdoor est.)',
#        '$145K-$225K(Employer est.)', '$79K-$147K (Glassdoor est.)',
#        '$122K-$146K (Glassdoor est.)', '$112K-$116K (Glassdoor est.)',
#        '$110K-$163K (Glassdoor est.)', '$124K-$198K (Glassdoor est.)',
#        '$79K-$133K (Glassdoor est.)', '$69K-$116K (Glassdoor est.)',
#        '$31K-$56K (Glassdoor est.)', '$95K-$119K (Glassdoor est.)',
#        '$212K-$331K (Glassdoor est.)', '$66K-$112K (Glassdoor est.)',
#        '$128K-$201K (Glassdoor est.)', '$138K-$158K (Glassdoor est.)',
#        '$80K-$132K (Glassdoor est.)', '$87K-$141K (Glassdoor est.)',
#        '$92K-$155K (Glassdoor est.)', '$105K-$167K (Glassdoor est.)'],
#       dtype=object)

# %% [markdown]
# - ### Problems
#     * have unnecessary content(eg, Glassdoor est.)
#     * have signs that can be turn into number (K=1000)
#
#
# - ### Solutions
#     * drop, strip or replace such contents
#     * create a salary range column for the purpose of more data analysis

# %%
# replacing Glassdoor est. 
df["salary_estimate"]=df["salary_estimate"].replace("Glassdoor est.","",regex=True).str.strip("(").str.strip(")")

# %%
# replacing Employer est. 
df["salary_estimate"]=df["salary_estimate"].replace("Employer est.","",regex=True).str.strip("(")

# %%
# Define a function to extract and create intervals
def extract_salary_range(salary_estimate):
    parts = salary_estimate.split('-')
    lower_bound = int(parts[0].strip('$').strip('K'))*1000
    upper_bound = int(parts[1].strip('$').replace('K',''))*1000
    
    avg=np.average(np.arange(lower_bound,upper_bound))
    return [f"{lower_bound}-{upper_bound}",lower_bound,upper_bound,avg]

# %%
df["salary_range($)"],df["min_salary"],df["max_salary"],df["avg_salary"]= zip(*df['salary_estimate'].apply(extract_salary_range))

# %%
df[["salary_estimate","salary_range($)"]].sample(10)
# Out:
#       salary_estimate salary_range($)
# index
# 561      $128K-$201K    128000-201000
# 592       $80K-$132K     80000-132000
# 493       $95K-$119K     95000-119000
# 462       $69K-$116K     69000-116000
# 341       $79K-$147K     79000-147000
# 654      $105K-$167K    105000-167000
# 466       $69K-$116K     69000-116000
# 513      $212K-$331K    212000-331000
# 498       $95K-$119K     95000-119000
# 405      $110K-$163K    110000-163000

# %%
df
# Out:
#                job_title salary_estimate  \
# index
# 0      Sr Data Scientist    $137K-$171K
# 1         Data Scientist    $137K-$171K
# 2         Data Scientist    $137K-$171K
# 3         Data Scientist    $137K-$171K
# 4         Data Scientist    $137K-$171K
# ...                  ...             ...
# 667       Data Scientist    $105K-$167K
# 668       Data Scientist    $105K-$167K
# 669       Data Scientist    $105K-$167K
# 670       Data Scientist    $105K-$167K
# 671       Data Scientist    $105K-$167K
#
#                                          job_description  rating  \
# index
# 0      Description\n\nThe Senior Data Scientist is re...     3.1
# 1      Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2      Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3      JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4      Data Scientist\nAffinity Solutions / Marketing...     2.9
# ...                                                  ...     ...
# 667    Summary\n\nWe’re looking for a data scientist ...     3.6
# 668    Job Description\nBecome a thought leader withi...    -1.0
# 669    Join a thriving company that is changing the w...    -1.0
# 670    100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671    Description\n\nThe Data Scientist will be part...     2.7
#
#                     company_name           location            headquarters  \
# index
# 0               Healthfirst\n3.1       New York, NY            New York, NY
# 1                   ManTech\n4.2      Chantilly, VA             Herndon, VA
# 2            Analysis Group\n3.8         Boston, MA              Boston, MA
# 3                   INFICON\n3.5         Newton, MA  Bad Ragaz, Switzerland
# 4        Affinity Solutions\n2.9       New York, NY            New York, NY
# ...                          ...                ...                     ...
# 667                TRANZACT\n3.6       Fort Lee, NJ            Fort Lee, NJ
# 668                         JKGT  San Francisco, CA                      -1
# 669                   AccessHope      Irwindale, CA                      -1
# 670    ChaTeck Incorporated\n5.0  San Francisco, CA         Santa Clara, CA
# 671           1-800-Flowers\n2.7       New York, NY         Carle Place, NY
#
#                           size  founded        type_of_ownership  ...  \
# index                                                             ...
# 0       1001 to 5000 employees     1993   Nonprofit Organization  ...
# 1      5001 to 10000 employees     1968         Company - Public  ...
# 2       1001 to 5000 employees     1981  Private Practice / Firm  ...
# 3        501 to 1000 employees     2000         Company - Public  ...
# 4          51 to 200 employees     1998        Company - Private  ...
# ...                        ...      ...                      ...  ...
# 667     1001 to 5000 employees     1989        Company - Private  ...
# 668                         -1       -1                       -1  ...
# 669                         -1       -1                       -1  ...
# 670          1 to 50 employees       -1        Company - Private  ...
# 671     1001 to 5000 employees     1976         Company - Public  ...
#
#                   sector                     revenue  \
# index
# 0              Insurance    Unknown / Non-Applicable
# 1      Business Services      $1 to $2 billion (USD)
# 2      Business Services  $100 to $500 million (USD)
# 3          Manufacturing  $100 to $500 million (USD)
# 4      Business Services    Unknown / Non-Applicable
# ...                  ...                         ...
# 667    Business Services    Unknown / Non-Applicable
# 668                   -1                          -1
# 669                   -1                          -1
# 670    Business Services      $1 to $5 million (USD)
# 671    Business Services      $1 to $2 billion (USD)
#
#                                              competitors       main_role  \
# index
# 0                EmblemHealth, UnitedHealth Group, Aetna  data scientist
# 1                                                     -1  data scientist
# 2                                                     -1  data scientist
# 3      MKS Instruments, Pfeiffer Vacuum, Agilent Tech...  data scientist
# 4                   Commerce Signals, Cardlytics, Yodlee  data scientist
# ...                                                  ...             ...
# 667                                                   -1  data scientist
# 668                                                   -1  data scientist
# 669                                                   -1  data scientist
# 670                                                   -1  data scientist
# 671                                                   -1  data scientist
#
#       seniority sub_role salary_range($) min_salary  max_salary  avg_salary
# index
# 0            Sr      Sr    137000-171000     137000      171000    153999.5
# 1       neutral            137000-171000     137000      171000    153999.5
# 2       neutral            137000-171000     137000      171000    153999.5
# 3       neutral            137000-171000     137000      171000    153999.5
# 4       neutral            137000-171000     137000      171000    153999.5
# ...         ...      ...             ...        ...         ...         ...
# 667     neutral            105000-167000     105000      167000    135999.5
# 668     neutral            105000-167000     105000      167000    135999.5
# 669     neutral            105000-167000     105000      167000    135999.5
# 670     neutral            105000-167000     105000      167000    135999.5
# 671     neutral            105000-167000     105000      167000    135999.5
#
# [672 rows x 21 columns]

# %%
# drop original salary_estimate column
df.drop("salary_estimate",axis=1,inplace=True)

# %%
## example for further analysis
import seaborn
# Function to parse salary range string and convert to NumPy range
def parse_salary_range(salary_range):
    lower, upper = map(int, salary_range.split('-'))
    return np.arange(lower, upper + 1)  # +1 to include the upper bound

# Apply the parsing function to the 'SalaryRange' column
salary_range=np.concatenate(df["salary_range($)"].apply(parse_salary_range))

# %%
import seaborn as sns
# Create a distribution plot using Seaborn
plt.figure(figsize=(10, 6))
sns.histplot(salary_range, bins=20, kde=True)
plt.xlabel('Salary Range')
plt.ylabel('Frequency')
plt.title('Salary Range Distribution')
plt.show()

# %% [markdown]
# ## Company name
#
# - ### Problems
#     * have unnecessary content (company version Healthfirst,4.1...)
#
#
# - ### Solutions
#     * drop, strip or replace such contents|

# %%
df.company_name
# Out:
# index
# 0               Healthfirst
# 1                   ManTech
# 2            Analysis Group
# 3                   INFICON
# 4        Affinity Solutions
#                ...
# 667                TRANZACT
# 668                    JKGT
# 669              AccessHope
# 670    ChaTeck Incorporated
# 671           1-800-Flowers
# Name: company_name, Length: 672, dtype: object

# %%
df["company_name"]=df.company_name.str.split("\n").str[0]

# %%
df.sample(10)
# Out:
#                               job_title  \
# index
# 403                    Sr. Data Analyst
# 81                       Data Scientist
# 338                      Data Scientist
# 142               Senior Data Scientist
# 287                      Data Scientist
# 164             Computational Scientist
# 659                      Data Scientist
# 8      Staff Data Scientist - Analytics
# 160                      Data Scientist
# 137                      Data Scientist
#
#                                          job_description  rating  \
# index
# 403    Position Overview:\n\nThe Sr. Data Analyst pla...     3.6
# 81     The Senior Data Scientist will build and impro...     3.6
# 338    Work in a fast growing startup with unlimited ...    -1.0
# 142    Tempo Automation is the world's fastest electr...     3.3
# 287    For many of our team members, this is more tha...     4.2
# 164    Type of Requisition:\n\nRegular\n\nClearance L...     3.4
# 659    Position is in support of the U.S. Army CCDC C...     3.2
# 8      Intuit is seeking a Staff Data Scientist to co...     4.4
# 160    The world's largest and fastest-growing compan...     4.5
# 137    Upstart is a leading AI lending platform partn...     4.2
#
#                                   company_name           location  \
# index
# 403                Community Behavioral Health   Philadelphia, PA
# 81                                    Powertek     Washington, DC
# 338                              Stride Search  San Francisco, CA
# 142                           Tempo Automation  San Francisco, CA
# 287                        Oshkosh Corporation        Oshkosh, WI
# 164    General Dynamics Information Technology      Vicksburg, MS
# 659                                  Perspecta        Adelphi, MD
# 8                                Intuit - Data      San Diego, CA
# 160                                 Demandbase  San Francisco, CA
# 137                                    Upstart      San Mateo, CA
#
#                headquarters                     size  founded  \
# index
# 403               Phila, PA     201 to 500 employees     1994
# 81            Rockville, MD      51 to 200 employees     2001
# 338    Westlake Village, CA        1 to 50 employees       -1
# 142       San Francisco, CA      51 to 200 employees     2013
# 287             Oshkosh, WI         10000+ employees     1917
# 164             Fairfax, VA         10000+ employees     1996
# 659           Chantilly, VA         10000+ employees     2018
# 8         Mountain View, CA  5001 to 10000 employees     1983
# 160       San Francisco, CA     201 to 500 employees     2006
# 137           San Mateo, CA     201 to 500 employees     2012
#
#                     type_of_ownership                                industry  \
# index
# 403                 Company - Private        Health Care Services & Hospitals
# 81                  Company - Private                             IT Services
# 338                 Company - Private                                      -1
# 142                 Company - Private   Electrical & Electronic Manufacturing
# 287                  Company - Public  Transportation Equipment Manufacturing
# 164    Subsidiary or Business Segment                             IT Services
# 659                  Company - Public                     Aerospace & Defense
# 8                    Company - Public            Computer Hardware & Software
# 160                 Company - Private            Computer Hardware & Software
# 137                 Company - Private                                 Lending
#
#                        sector                           revenue  \
# index
# 403               Health Care  $500 million to $1 billion (USD)
# 81     Information Technology          $25 to $50 million (USD)
# 338                        -1        Less than $1 million (USD)
# 142             Manufacturing           $5 to $10 million (USD)
# 287             Manufacturing           $5 to $10 billion (USD)
# 164    Information Technology                $10+ billion (USD)
# 659       Aerospace & Defense          Unknown / Non-Applicable
# 8      Information Technology            $2 to $5 billion (USD)
# 160    Information Technology        $100 to $500 million (USD)
# 137                   Finance          Unknown / Non-Applicable
#
#                                     competitors  \
# index
# 403                                          -1
# 81                                           -1
# 338                                          -1
# 142                                          -1
# 287    Lockheed Martin, Caterpillar, John Deere
# 164              SAIC, Leidos, Northrop Grumman
# 659                                          -1
# 8                     Square, PayPal, H&R Block
# 160                  Engagio, Bombora, Terminus
# 137                                          -1
#
#                                                main_role seniority  \
# index
# 403                                 data analyst/analyst        Sr
# 81                                        data scientist   neutral
# 338                                       data scientist   neutral
# 142                                       data scientist        Sr
# 287                                       data scientist   neutral
# 164    others/scientist/software engineer(data concer...   neutral
# 659                                       data scientist   neutral
# 8                                         data scientist        jr
# 160                                       data scientist   neutral
# 137                                       data scientist   neutral
#
#                       sub_role salary_range($)  min_salary  max_salary  \
# index
# 403                       Sr.    110000-163000      110000      163000
# 81                                79000-131000       79000      131000
# 338                               79000-147000       79000      147000
# 142                    Senior     90000-109000       90000      109000
# 287                              141000-225000      141000      225000
# 164    Computational Scientist   101000-165000      101000      165000
# 659                              105000-167000      105000      167000
# 8           Staff  - Analytics   137000-171000      137000      171000
# 160                              101000-165000      101000      165000
# 137                               90000-109000       90000      109000
#
#        avg_salary
# index
# 403      136499.5
# 81       104999.5
# 338      112999.5
# 142       99499.5
# 287      182999.5
# 164      132999.5
# 659      135999.5
# 8        153999.5
# 160      132999.5
# 137       99499.5

# %% [markdown]
# ## location & headquarters
#
# - ### Problems
#     * location column show (company city, company state) which can be shown in separate columns
#     * headquarters column show (headquarter city, headQuarter state) which can be shown in separate columns
#
#
# - ### Solutions
#     * create separate columns to show city and state

# %%
def createCityState(location:pd.Series):

    
    city=location.str.split(",").str[0]
    state=location.str.split(",").str[1]
    
    return city,state

# %%
df=df.assign(company_city=createCityState(df["location"])[0],  company_state=createCityState(df["location"])[1])
df=df.assign(headquarter_city=createCityState(df["headquarters"])[0],  headquarter_state=createCityState(df["headquarters"])[1])

# %%
df.sample(10)
# Out:
#                                                job_title  \
# index
# 427                                       Data Scientist
# 275                                       Data Scientist
# 579    Scientist/Research Associate-Metabolic Enginee...
# 138                                         Data Analyst
# 161                            Say Business Data Analyst
# 602                                   Decision Scientist
# 458                            Machine Learning Engineer
# 351                                       Data Scientist
# 617                                       Data Scientist
# 194                 Senior Data Scientist - R&D Oncology
#
#                                          job_description  rating  \
# index
# 427    As a Data Scientist, you'll utilize advanced q...     3.7
# 275    Join us and make YOUR mark on the World!\n\nCo...     4.7
# 579    *Our company:\n*Conagen Inc. is a leader in cu...     2.0
# 138    Data Analyst -San Francisco\n\nNo C2C or spons...     4.5
# 161    A company built to serve you. It's your career...     4.1
# 602    Are you passionate about Decision Science?\n\n...     4.5
# 458    What We Do:\n\nAt the SEI Emerging Technology ...     2.6
# 351    About Our AI/ML Team\n\nOur mission is to buil...    -1.0
# 617    Data Engineer\n\nDescription\nUST Global is lo...     4.2
# 194    At AstraZeneca,we work together to deliver inn...     4.0
#
#                                             company_name           location  \
# index
# 427                                   Via Transportation       New York, NY
# 275                      Lawrence Livermore National Lab      Livermore, CA
# 579                                              Conagen    New Bedford, MA
# 138                                         Envision LLC  San Francisco, CA
# 161                                    Shelter Insurance       Columbia, MO
# 602    Johns Hopkins University Applied Physics Labor...         Laurel, MD
# 458                       Software Engineering Institute     Pittsburgh, PA
# 351                                     Point72 Ventures      Palo Alto, CA
# 617                                           UST Global        Atlanta, GA
# 194                                          AstraZeneca       New York, NY
#
#                     headquarters                     size  founded  \
# index
# 427                 New York, NY    501 to 1000 employees     2012
# 275                Livermore, CA   1001 to 5000 employees     1952
# 579                  Bedford, MA      51 to 200 employees       -1
# 138              Saint Louis, MO     201 to 500 employees     1994
# 161                 Columbia, MO   1001 to 5000 employees     1946
# 602                   Laurel, MD  5001 to 10000 employees     1942
# 458               Pittsburgh, PA    501 to 1000 employees     1984
# 351                           -1                       -1       -1
# 617              Aliso Viejo, CA         10000+ employees     1999
# 194    Cambridge, United Kingdom         10000+ employees     1913
#
#             type_of_ownership                   industry  ... seniority  \
# index                                                     ...
# 427         Company - Private                   Internet  ...   neutral
# 275                Government           Federal Agencies  ...   neutral
# 579         Company - Private  Biotech & Pharmaceuticals  ...   neutral
# 138         Company - Private     Staffing & Outsourcing  ...   neutral
# 161         Company - Private         Insurance Carriers  ...   neutral
# 602    Nonprofit Organization        Aerospace & Defense  ...   neutral
# 458      College / University    Colleges & Universities  ...   neutral
# 351                        -1                         -1  ...   neutral
# 617         Company - Private                IT Services  ...   neutral
# 194          Company - Public  Biotech & Pharmaceuticals  ...        Sr
#
#                                                 sub_role salary_range($)  \
# index
# 427                                                         79000-133000
# 275                                                         91000-150000
# 579    Scientist/Research Associate-Metabolic Enginee...   138000-158000
# 138                                                         90000-109000
# 161                                        Say Business    101000-165000
# 602                                   Decision Scientist    80000-132000
# 458                                             Engineer    69000-116000
# 351                                                        122000-146000
# 617                                                         87000-141000
# 194                               Senior  - R&D Oncology     56000-97000
#
#       min_salary max_salary avg_salary   company_city  company_state  \
# index
# 427        79000     133000   105999.5       New York             NY
# 275        91000     150000   120499.5      Livermore             CA
# 579       138000     158000   147999.5    New Bedford             MA
# 138        90000     109000    99499.5  San Francisco             CA
# 161       101000     165000   132999.5       Columbia             MO
# 602        80000     132000   105999.5         Laurel             MD
# 458        69000     116000    92499.5     Pittsburgh             PA
# 351       122000     146000   133999.5      Palo Alto             CA
# 617        87000     141000   113999.5        Atlanta             GA
# 194        56000      97000    76499.5       New York             NY
#
#        headquarter_city  headquarter_state
# index
# 427            New York                 NY
# 275           Livermore                 CA
# 579             Bedford                 MA
# 138         Saint Louis                 MO
# 161            Columbia                 MO
# 602              Laurel                 MD
# 458          Pittsburgh                 PA
# 351                  -1                NaN
# 617         Aliso Viejo                 CA
# 194           Cambridge     United Kingdom
#
# [10 rows x 24 columns]
