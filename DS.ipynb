# %%
import pandas as pd
import hvplot.pandas 
import panel as pn
import numpy as np

pn.extension("tabulator")
# Out:
# %opts magic unavailable (pyparsing cannot be imported)
# %compositor magic unavailable (pyparsing cannot be imported)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="aaeae66d-83ca-4af7-944e-2f368b96b379" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"59f76bc2-60b1-4a0b-999a-d15d53e3781d":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"f71bf0fb654f49eb92386f5e5e29a198","client_comm_id":"ff1d65b3044a4699ad9b36b306d79e80"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"59f76bc2-60b1-4a0b-999a-d15d53e3781d","roots":{"p1002":"aaeae66d-83ca-4af7-944e-2f368b96b379"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df=pd.read_csv("Cleaned_DS_jobs.csv")

# %%
df.sample(10)
# Out:
#                                              job_title  rating  \
# 411                                     Data Scientist    -1.0
# 380                      Analytics Manager - Data Mart     3.5
# 0                                    Sr Data Scientist     3.1
# 119                                      Data Engineer     4.8
# 535              Machine Learning Scientist / Engineer     4.1
# 255                                     Data Scientist     3.9
# 198        Analytics - Business Assurance Data Analyst     4.6
# 589  Hydrogen/Tritium Materials Scientist (Experien...     3.8
# 576                                Senior Data Analyst     4.5
# 472                              Data Engineer - Kafka     3.5
#
#                                company_name       type_of_ownership  \
# 411                                Evolvinc       Company - Private
# 380  Central California Alliance for Health  Nonprofit Organization
# 0                               Healthfirst  Nonprofit Organization
# 119                          GetWellNetwork       Company - Private
# 535                                   Apple        Company - Public
# 255                   Rapid Value Solutions       Company - Private
# 198         GreatAmerica Financial Services       Company - Private
# 589            Sandia National Laboratories              Government
# 576                                 Novetta       Company - Private
# 472                         Western Digital        Company - Public
#
#                                     industry                  sector  \
# 411                              IT Services  Information Technology
# 380         Health Care Services & Hospitals             Health Care
# 0                         Insurance Carriers               Insurance
# 119         Health Care Services & Hospitals             Health Care
# 535             Computer Hardware & Software  Information Technology
# 255                              IT Services  Information Technology
# 198                                  Lending                 Finance
# 589                         Federal Agencies              Government
# 576  Enterprise Software & Network Solutions  Information Technology
# 472             Computer Hardware & Software  Information Technology
#
#             revenue                                          main_role  \
# 411         Unknown                                     data scientist
# 380    $500M to $1B  others/scientist/software engineer(data concer...
# 0           Unknown                                     data scientist
# 119   $50M to $100M                                      data engineer
# 535           $10B+                  AI/ machine learning professionle
# 255         Unknown                                     data scientist
# 198  $100M to $500M                               data analyst/analyst
# 589      $2B to $5B  others/scientist/software engineer(data concer...
# 576  $100M to $500M                               data analyst/analyst
# 472           $10B+                                      data engineer
#
#     seniority                                           sub_role  \
# 411   neutral                                                NaN
# 380   neutral                      Analytics Manager - Data Mart
# 0          Sr                                                Sr
# 119   neutral                                                NaN
# 535   neutral                               Scientist / Engineer
# 255   neutral                                                NaN
# 198   neutral                    Analytics - Business Assurance
# 589        Sr  Hydrogen/Tritium Materials Scientist (Experien...
# 576        Sr                                            Senior
# 472   neutral                                            - Kafka
#
#     salary_range($)  min_salary  max_salary  avg_salary   company_city  \
# 411   124000-198000      124000      198000    160999.5        Burbank
# 380   112000-116000      112000      116000    113999.5  Scotts Valley
# 0     137000-171000      137000      171000    153999.5       New York
# 119    99000-132000       99000      132000    115499.5       Bethesda
# 535    66000-112000       66000      112000     88999.5    Santa Clara
# 255    90000-124000       90000      124000    106999.5  San Francisco
# 198     56000-97000       56000       97000     76499.5   Cedar Rapids
# 589   138000-158000      138000      158000    147999.5      Livermore
# 576   138000-158000      138000      158000    147999.5        Herndon
# 472     31000-56000       31000       56000     43499.5       San Jose
#
#     company_state headquarter_city headquarter_state company_size_category  \
# 411            CA      Los Angeles                CA                 Small
# 380            CA    Scotts Valley                CA                Medium
# 0              NY         New York                NY                 Large
# 119            MD         Bethesda                MD                Medium
# 535            CA        Cupertino                CA            Very Large
# 255            CA       Pleasanton                CA                Medium
# 198            IA     Cedar Rapids                IA                Medium
# 589            CA      Albuquerque                NM            Very Large
# 576            VA          Mc Lean                VA                Medium
# 472            CA         San Jose                CA            Very Large
#
#     founded_year_category
# 411           2000s-2010s
# 380           1990s-2000s
# 0             1990s-2000s
# 119           1990s-2000s
# 535           1970s-1980s
# 255           2000s-2010s
# 198           1990s-2000s
# 589           1900s-1950s
# 576           2010s-2020s
# 472           1960s-1970s

# %% [markdown]
# # (0) Basic Understanding of background info

# %%
df.columns## columns of dataframe
# Out:
# Index(['job_title', 'rating', 'company_name', 'type_of_ownership', 'industry',
#        'sector', 'revenue', 'main_role', 'seniority', 'sub_role',
#        'salary_range($)', 'min_salary', 'max_salary', 'avg_salary',
#        'company_city', 'company_state', 'headquarter_city',
#        'headquarter_state', 'company_size_category', 'founded_year_category'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title              672 non-null    object
#  1   rating                 672 non-null    float64
#  2   company_name           672 non-null    object
#  3   type_of_ownership      672 non-null    object
#  4   industry               672 non-null    object
#  5   sector                 672 non-null    object
#  6   revenue                672 non-null    object
#  7   main_role              672 non-null    object
#  8   seniority              672 non-null    object
#  9   sub_role               297 non-null    object
#  10  salary_range($)        672 non-null    object
#  11  min_salary             672 non-null    int64
#  12  max_salary             672 non-null    int64
#  13  avg_salary             672 non-null    float64
#  14  company_city           672 non-null    object
#  15  company_state          649 non-null    object
#  16  headquarter_city       672 non-null    object
#  17  headquarter_state      641 non-null    object
#  18  company_size_category  672 non-null    object
#  19  founded_year_category  554 non-null    object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 105.1+ KB

# %%
df.main_role.unique()
# Out:
# array(['data scientist', 'AI/ machine learning professionle',
#        'others/scientist/software engineer(data concerning role)',
#        'data analyst/analyst', 'data engineer'], dtype=object)

# %%
df.describe()
# Out:
#            rating     min_salary     max_salary     avg_salary
# count  672.000000     672.000000     672.000000     672.000000
# mean     3.518601   99196.428571  148130.952381  123663.190476
# std      1.410329   33009.958111   48035.110051   39580.267895
# min     -1.000000   31000.000000   56000.000000   43499.500000
# 25%      3.300000   79000.000000  119000.000000  102999.500000
# 50%      3.800000   91000.000000  133000.000000  113999.500000
# 75%      4.300000  122000.000000  165000.000000  136499.500000
# max      5.000000  212000.000000  331000.000000  271499.500000

# %%
## make data frame interactave
idf=df.interactive()

# %% [markdown]
# # INSIGHT GAINED FROM ANALYSIS
# 1. average,min, max salary of each role
# 2. correlation between company matching parameters(e.g. type of owner ship, sector...) and average salary
# 3. correlation between seneriority and average salary
# 4. correlation between location and average salary

# %% [markdown]
# ## 1. Average,min,max salary of each role

# %%
## create a selector
roles_selector=pn.widgets.Select(
    name="Choose the role",
    options=df.main_role.unique().tolist(),
)
roles_selector
# Out:
# Select(name='Choose the role', options=['data scientist', ...], value='data scientist')

# %%
## create a pipe line and connect it with the widget

role_data=(
    idf[idf.main_role==roles_selector]
    .groupby("main_role")[["min_salary","max_salary","avg_salary"]].mean()
)

# %%
## role table views
role_table=role_data.pipe(pn.widgets.Tabulator,pagination='remote',page_size=10,sizing_mode='stretch_width')
role_table
# Out:
# <div id='c9ba10ad-81b3-4862-a154-2f0b7bfe5038'>
#   <div id="a3eb7e0a-3d4b-47d7-9f20-bfd2caeeaa26" data-root-id="c9ba10ad-81b3-4862-a154-2f0b7bfe5038" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8828b76f-620f-469d-8c14-38c3b9972d13":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"c9ba10ad-81b3-4862-a154-2f0b7bfe5038","attributes":{"name":"Row01369","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"cb78eedc-38c2-4a60-8311-1ac99f7d3485","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"e69b0302-cf2c-45ae-9ef6-e3fc46882a60","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7fa08052-8daf-463a-adac-69d55adb5f2c","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8621647e-1ee8-4c14-9134-633b98ad7997","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"8a6dced5-6f3c-4b98-a8ba-919102b4fa2e","attributes":{"name":"Column01366","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"cb78eedc-38c2-4a60-8311-1ac99f7d3485"},{"id":"e69b0302-cf2c-45ae-9ef6-e3fc46882a60"},{"id":"7fa08052-8daf-463a-adac-69d55adb5f2c"},{"id":"8621647e-1ee8-4c14-9134-633b98ad7997"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"24cfcfc6-8b6a-4cc3-9467-c7b5bf550207","attributes":{"name":"Column01348","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"cb78eedc-38c2-4a60-8311-1ac99f7d3485"},{"id":"e69b0302-cf2c-45ae-9ef6-e3fc46882a60"},{"id":"7fa08052-8daf-463a-adac-69d55adb5f2c"},{"id":"8621647e-1ee8-4c14-9134-633b98ad7997"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"baab9baa-770c-40ec-a39b-4a0f9fb076ce","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"cb78eedc-38c2-4a60-8311-1ac99f7d3485"},{"type":"object","name":"ImportedStyleSheet","id":"187409a6-359d-4502-b73d-e7c3a764df63","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/select.css"}},{"id":"7fa08052-8daf-463a-adac-69d55adb5f2c"},{"id":"8621647e-1ee8-4c14-9134-633b98ad7997"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Choose the role","options":["data scientist","AI/ machine learning professionle","others/scientist/software engineer(data concerning role)","data analyst/analyst","data engineer"],"value":"data scientist"}}]}},{"type":"object","name":"panel.models.layout.Column","id":"36e89efc-b197-4a38-aaf0-5589a91a7e25","attributes":{"name":"Column01363","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"cb78eedc-38c2-4a60-8311-1ac99f7d3485"},{"id":"e69b0302-cf2c-45ae-9ef6-e3fc46882a60"},{"id":"7fa08052-8daf-463a-adac-69d55adb5f2c"},{"id":"8621647e-1ee8-4c14-9134-633b98ad7997"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.tabulator.DataTabulator","id":"5293e9d0-7e50-4193-a4c8-dd5e8bf71700","attributes":{"subscribed_events":{"type":"set","entries":["cell-click","table-edit"]},"stylesheets":["\ ...

# %% [markdown]
# ## 2.correlation between company matching parameters(e.g. type of owner ship, sector...) and average salary

# %%
## create a radio_button
XAxisSelector=pn.widgets.RadioButtonGroup(
    name="X axis",
    options=["type_of_ownership","sector","company_size_category","founded_year_category"],
    button_type="success"
)
XAxisSelector
# Out:
# RadioButtonGroup(button_type='success', name='X axis', options=['type_of_ownership', ...], value='type_of_ownership')

# %%
## pipe line creattion
company_salary_pipeline=(
    idf[idf.main_role==roles_selector]
    .groupby(XAxisSelector)["avg_salary"].mean().head(5)
    .to_frame()
    .reset_index()
    .sort_values(by="avg_salary",ascending=False)
    .reset_index(drop=True)
)
company_salary_pipeline
# Out:
# <div id='3fa51750-5c31-4e6a-813e-9876ee124696'>
#   <div id="e47cfea3-b605-4b9e-b7e1-73cdc8d8c8f9" data-root-id="3fa51750-5c31-4e6a-813e-9876ee124696" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"824ee29a-684c-4738-be49-301f3ad5f529":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"3fa51750-5c31-4e6a-813e-9876ee124696","attributes":{"name":"Row02151","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"2f7ae516-770b-4462-a0b2-3285e7bbb567","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"95e477ae-6cf7-4ceb-be03-95316c8ce544","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"e1500f80-3bb1-40af-acb1-55241679a646","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"11081c1d-3d8e-4670-b66b-f58694d84f64","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"3bd31329-8864-4728-ba67-0d99a9d776d1","attributes":{"name":"Column02148","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2f7ae516-770b-4462-a0b2-3285e7bbb567"},{"id":"95e477ae-6cf7-4ceb-be03-95316c8ce544"},{"id":"e1500f80-3bb1-40af-acb1-55241679a646"},{"id":"11081c1d-3d8e-4670-b66b-f58694d84f64"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"e976aa21-ce14-4275-9443-cb9d1f718df4","attributes":{"name":"Column02118","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2f7ae516-770b-4462-a0b2-3285e7bbb567"},{"id":"95e477ae-6cf7-4ceb-be03-95316c8ce544"},{"id":"e1500f80-3bb1-40af-acb1-55241679a646"},{"id":"11081c1d-3d8e-4670-b66b-f58694d84f64"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"26d0a0a9-ae58-4cf0-a68d-29e96c06d916","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2f7ae516-770b-4462-a0b2-3285e7bbb567"},{"type":"object","name":"ImportedStyleSheet","id":"158fa50b-82be-444b-921d-45de7d7ae0b3","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/select.css"}},{"id":"e1500f80-3bb1-40af-acb1-55241679a646"},{"id":"11081c1d-3d8e-4670-b66b-f58694d84f64"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Choose the role","options":["data scientist","AI/ machine learning professionle","others/scientist/software engineer(data concerning role)","data analyst/analyst","data engineer"],"value":"data scientist"}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"6c3e1b19-5940-4c02-82c7-d6d206a0f857","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"2f7ae516-770b-4462-a0b2-3285e7bbb567"},{"type":"object","name":"ImportedStyleSheet","id":"58e827d6-6400-4d9a-a396-e85eefd235b5","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/button.css"}},{"id":"e1500f80-3bb1-40af-acb1-55241679a646"},{"id":"11081c1d-3d8e-4670-b66b-f58694d84f64"}],"margin":[5,10],"align":"start","labels":["type_of_ownership","sector","company_size_category","founded_year_category"],"active":0}}]}},{"type":"object","name":"panel.models.layout.C ...

# %%
## barchart creation
company_salary_barplot=company_salary_pipeline.hvplot.bar(x=XAxisSelector,y="avg_salary")
company_salary_barplot
# Out:
# <div id='2dda777a-2ba5-44e5-9940-ad9922f487e2'>
#   <div id="f5d15615-e832-42dc-a939-a06f1a7c075e" data-root-id="2dda777a-2ba5-44e5-9940-ad9922f487e2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"
#x27; NJ&#x27; &#x27; LA&#x27; &#x27; OH&#x27; &#x27; IN&#x27; &#x27; MD&#x27;\n &#x27; CO&#x27; &#x27; UT&#x27; &#x27; OR&#x27; &#x27; MI&#x27; &#x27; SC&#x27; &#x27; MS&#x27; &#x27; AL&#x27; &#x27; RI&#x27; &#x27; IA&#x27; &#x27; MN&#x27; &#x27; OK&#x27; &#x27; CT&#x27;\n &#x27; NC&#x27; &#x27; DE&#x27; &#x27; Anne Arundel&#x27; &#x27; WV&#x27;]&lt;/pre&gt;"}}]}}]}}]}},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"6dd ...

# %%
## create data pipeline
state_salary_pipeline=(
    idf[idf.main_role==roles_selector]
    .groupby("company_state")["avg_salary"].mean()
    .to_frame()
    .reset_index()
    .sort_values(by="avg_salary",ascending=False)
    .reset_index(drop=True)
)

state_salary_pipeline
# Out:
# <div id='53ac73bc-7e67-4892-9608-399bb14b9076'>
#   <div id="ef5b2047-d676-4e58-95ec-3d38f1a204ba" data-root-id="53ac73bc-7e67-4892-9608-399bb14b9076" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f8588655-4b81-45cb-9b13-93e1d82e8d68":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"53ac73bc-7e67-4892-9608-399bb14b9076","attributes":{"name":"Row04103","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"8500e016-1003-493c-872f-1d08673df0e5","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1d434d03-46d1-4bc8-9d76-a36969386c22","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"cadd760f-cde6-4eb8-8877-04cb8ed0b2eb","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"9ac807bd-4daf-4e0e-b6f4-2189f61894aa","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"fb8edc32-ba07-47c4-9464-596b83cd5d17","attributes":{"name":"Column04100","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8500e016-1003-493c-872f-1d08673df0e5"},{"id":"1d434d03-46d1-4bc8-9d76-a36969386c22"},{"id":"cadd760f-cde6-4eb8-8877-04cb8ed0b2eb"},{"id":"9ac807bd-4daf-4e0e-b6f4-2189f61894aa"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"c6140162-fb9e-4284-9cd6-703a7733fc4b","attributes":{"name":"Column04070","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8500e016-1003-493c-872f-1d08673df0e5"},{"id":"1d434d03-46d1-4bc8-9d76-a36969386c22"},{"id":"cadd760f-cde6-4eb8-8877-04cb8ed0b2eb"},{"id":"9ac807bd-4daf-4e0e-b6f4-2189f61894aa"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"0b96ecd2-d9d5-4b2f-8a6e-2c92ed20392a","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8500e016-1003-493c-872f-1d08673df0e5"},{"type":"object","name":"ImportedStyleSheet","id":"2b3fbe2a-d2ab-45fc-8809-aa1bc844fc36","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/select.css"}},{"id":"cadd760f-cde6-4eb8-8877-04cb8ed0b2eb"},{"id":"9ac807bd-4daf-4e0e-b6f4-2189f61894aa"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Choose the role","options":["data scientist","AI/ machine learning professionle","others/scientist/software engineer(data concerning role)","data analyst/analyst","data engineer"],"value":"data scientist"}}]}},{"type":"object","name":"panel.models.layout.Column","id":"65d234ee-458b-479c-acaf-3ab3640a8695","attributes":{"name":"Column04085","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8500e016-1003-493c-872f-1d08673df0e5"},{"id":"1d434d03-46d1-4bc8-9d76-a36969386c22"},{"id":"cadd760f-cde6-4eb8-8877-04cb8ed0b2eb"},{"id":"9ac807bd-4daf-4e0e-b6f4-2189f61894aa"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"89c29aed-18d3-4e80-9c8a-365cf0e123cb","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}" ...

# %%
state_salary_plot=state_salary_pipeline.hvplot.bar(
    x="company_state",
    y="avg_salary",
)
state_salary_plot
# Out:
# <div id='7a359f80-91df-4708-8bc2-3053f8056bac'>
#   <div id="c38607d5-8b94-4eae-b1bc-e1b7284b0393" data-root-id="7a359f80-91df-4708-8bc2-3053f8056bac" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"008b54e2-a0f0-4f3d-b02d-933b750e95c9":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"7a359f80-91df-4708-8bc2-3053f8056bac","attributes":{"name":"Row04268","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"fd6326a6-404c-4b99-8f26-6c4cb747bfc0","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"0abe2f2f-1255-45d1-ac3d-75601118768a","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a6751fc6-245f-4e70-8d47-2e62fa08f8dc","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"6e611005-2291-4bec-bff7-fb7b8a5e13c5","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"de7ed6da-e82f-4703-8335-ab7f9e985c1d","attributes":{"name":"Column04265","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"fd6326a6-404c-4b99-8f26-6c4cb747bfc0"},{"id":"0abe2f2f-1255-45d1-ac3d-75601118768a"},{"id":"a6751fc6-245f-4e70-8d47-2e62fa08f8dc"},{"id":"6e611005-2291-4bec-bff7-fb7b8a5e13c5"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"036bc2e8-528b-4436-b2d9-c44f2c6c3752","attributes":{"name":"Column04248","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"fd6326a6-404c-4b99-8f26-6c4cb747bfc0"},{"id":"0abe2f2f-1255-45d1-ac3d-75601118768a"},{"id":"a6751fc6-245f-4e70-8d47-2e62fa08f8dc"},{"id":"6e611005-2291-4bec-bff7-fb7b8a5e13c5"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"d2cea4f4-f059-401f-ab1a-d3bab1eabd93","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"fd6326a6-404c-4b99-8f26-6c4cb747bfc0"},{"type":"object","name":"ImportedStyleSheet","id":"deeecba3-8ba6-4290-863e-576688e9e2cc","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.0/dist/css/select.css"}},{"id":"a6751fc6-245f-4e70-8d47-2e62fa08f8dc"},{"id":"6e611005-2291-4bec-bff7-fb7b8a5e13c5"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Choose the role","options":["data scientist","AI/ machine learning professionle","others/scientist/software engineer(data concerning role)","data analyst/analyst","data engineer"],"value":"data scientist"}}]}},{"type":"object","name":"Figure","id":"cc5b2328-e00e-437e-9439-3132e7fac02b","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"4646079d-9237-469d-bef8-f12e01257709","attributes":{"tags":[[["company_state","company_state",null]],[]],"factors":[" DE"," NH"," AZ"," WI"," DC"," NY"," TX"," PA"," NC"," WA"," VA"," FL"," CA"," NJ"," MI"," IL"," MD"," MA"," UT"," WV"," MO"," OH"," NE"," GA"," AL"," IN"," MN"," KS"," CO"," TN"," OR"," CT"," Anne Arundel"]}},"y_range":{"type":"object","name":"Range1d","id":"eb2860fe-0e92-4be7-97df-5dea852d534c","attributes":{"tags":[[["avg_salary","avg_salary",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"end":289749.5,"reset_start":0.0,"reset_end":289749.5}},"x_scale":{"type":"object", ...

# %%
## create a template
template=pn.template.FastListTemplate(
    title="Data Jobs Analysis by Nyi BO",
    sidebar=roles_selector,
    main=[pn.Row(pn.Column(role_table),pn.Column(seniority_salary_barplot.panel(width=500),margin=(0,25))),
         pn.Row(pn.Column(XAxisSelector,company_salary_barplot.panel(width=800),margin=(0,25))),
    pn.Row(pn.Column(XAxisSelector,state_salary_plot.panel(width=800),margin=(0,25)))]
)
template.servable();
